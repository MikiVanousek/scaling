# %%
import wandb
import pandas as pd

import torch
import torch.optim as optim
import numpy as np

# %%
entity="miki-and-tml"
project="scaling-tests"
api = wandb.Api()

runs = api.runs(f"{entity}/{project}")

datasets = ['MikiV_SimpleStories_SimpleStories_chunked_512', 'MikiV_SimpleStories_SimpleStories_subchunked_256x2',  'MikiV_SimpleStories_SimpleStories_subchunked_128x4']

val_cols = [f'final_val_loss{ci_suffix}_{dataset}' for dataset in datasets for ci_suffix in ['', '_ci_lower', '_ci_upper']]
dtypes = {
    'run_id': str, # or 'object'
    'tokens_seen': int, # or 'int64'
    'compute': float,
    'params': int
} 
dtypes.update({col: float for col in val_cols})

# 2. Create the empty DataFrame, using keys from dtypes as columns
runs_df = pd.DataFrame(columns=dtypes.keys())

for run in runs:
    summary = run.summary._json_dict
    
    # Extract final logged values, defaulting to None if not available
    row = {
        'run_id': run.id,
        'run_name': run.name,
    }
    row.update({col: summary.get(col) for col in dtypes.keys()})
    runs_df = pd.concat([pd.DataFrame([row]), runs_df]).reset_index(drop=True)

runs_df
# Out:
# wandb: Currently logged in as: vanousekmikulas (vanousekmikulas-epfl) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# /tmp/ipykernel_134240/2836687964.py:30: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   runs_df = pd.concat([pd.DataFrame([row]), runs_df]).reset_index(drop=True)
#    run_id                                    run_name tokens_seen  \
# 0    None  cfgs/simple_stories_chartok/512/14M/5.yaml  3839983616
# 1    None  cfgs/simple_stories_chartok/128/14M/5.yaml  3839983616
# 2    None  cfgs/simple_stories_chartok/256/14M/5.yaml  3839983616
# 3    None  cfgs/simple_stories_chartok/128/14M/4.yaml  1919975424
# 4    None  cfgs/simple_stories_chartok/512/14M/4.yaml  1919975424
# 5    None   cfgs/simple_stories_chartok/256/7M/5.yaml  1919975424
# 6    None  cfgs/simple_stories_chartok/256/14M/4.yaml  1919975424
# 7    None   cfgs/simple_stories_chartok/128/7M/5.yaml  1919975424
# 8    None  cfgs/simple_stories_chartok/128/14M/3.yaml   959971328
# 9    None   cfgs/simple_stories_chartok/512/7M/5.yaml  1919975424
# 10   None   cfgs/simple_stories_chartok/256/7M/4.yaml   959971328
# 11   None   cfgs/simple_stories_chartok/128/7M/4.yaml   959971328
# 12   None  cfgs/simple_stories_chartok/128/14M/2.yaml   479985664
# 13   None   cfgs/simple_stories_chartok/256/7M/3.yaml   479985664
# 14   None   cfgs/simple_stories_chartok/128/7M/3.yaml   479985664
# 15   None   cfgs/simple_stories_chartok/256/2M/5.yaml   431980544
# 16   None   cfgs/simple_stories_chartok/128/2M/5.yaml   431980544
# 17   None   cfgs/simple_stories_chartok/128/7M/2.yaml   239992832
# 18   None   cfgs/simple_stories_chartok/256/7M/2.yaml   239992832
# 19   None  cfgs/simple_stories_chartok/256/14M/3.yaml   959971328
# 20   None   cfgs/simple_stories_chartok/128/2M/4.yaml   215973888
# 21   None   cfgs/simple_stories_chartok/256/2M/4.yaml   215973888
# 22   None   cfgs/simple_stories_chartok/128/2M/3.yaml   107970560
# 23   None   cfgs/simple_stories_chartok/256/2M/3.yaml   107970560
# 24   None   cfgs/simple_stories_chartok/128/2M/2.yaml    53968896
# 25   None  cfgs/simple_stories_chartok/128/14M/1.yaml   239992832
# 26   None   cfgs/simple_stories_chartok/128/7M/1.yaml   119996416
# 27   None   cfgs/simple_stories_chartok/256/2M/2.yaml    53968896
# 28   None   cfgs/simple_stories_chartok/128/2M/1.yaml    26968064
# 29   None   cfgs/simple_stories_chartok/256/7M/1.yaml   119996416
# 30   None   cfgs/simple_stories_chartok/256/2M/1.yaml    26968064
# 31   None   cfgs/simple_stories_chartok/512/7M/4.yaml   959971328
# 32   None  cfgs/simple_stories_chartok/512/14M/3.yaml   959971328
# 33   None   cfgs/simple_stories_chartok/512/7M/3.yaml   479985664
# 34   None  cfgs/simple_stories_chartok/256/14M/2.yaml   479985664
# 35   None   cfgs/simple_stories_chartok/512/2M/5.yaml   431980544
# 36   None   cfgs/simple_stories_chartok/512/7M/2.yaml   239992832
# 37   None   cfgs/simple_stories_chartok/512/2M/4.yaml   215973888
# 38   None   cfgs/simple_stories_chartok/512/2M/3.yaml   107970560
# 39   None  cfgs/simple_stories_chartok/512/14M/2.yaml   479985664
# 40   None   cfgs/simple_stories_chartok/512/2M/2.yaml    53968896
# 41   None   cfgs/simple_stories_chartok/512/2M/1.yaml    26968064
# 42   None  cfgs/simple_stories_chartok/256/14M/1.yaml   239992832
# 43   None  cfgs/simple_stories_chartok/512/14M/1.yaml       32768
# 44   None   cfgs/simple_stories_chartok/512/7M/1.yaml   119996416
#
#               compute    params  \
# 0   46171225721929730  10715224
# 1   32422486943465470  10715224
# 2   37005399869620220  10715224
# 3   16211105135198208  10715224
# 4   23085415862894590  10715224
# 5    9315167804325888   4784216
# 6   18502542044430336  10715224
# 7    7787543198171136   4784216
# 8    8105414231064576  10715224
# 9   12370417016635392   4784216
# 10   4657504411713536   4784216
# 11   3893705144532992   4784216
# 12   4052707115532288  10715224
# 13   2328752205856768   4784216
# 14   1946852572266496   4784216
# 15    481274707836928    815960
# 16    365379511648256    815960
# 17    973426286133248   4784216
# 18   1164376102928384   4784216
# 19   9251113131835392  10715224
# 20    182675897843712    815960
# 21    240619100307456    815960
# 22     91324090941440    815960
# 23    120291296542720    815960
# 24     45648187490304    815960
# 25   2026353557766144  10715224
# 26    486713143066624   4784216
# 27     60127394660352    815960
# 28     22810235764736    815960
# 29    582188051464192   4784216
# 30     30045443719168    815960
# 31   6185102946074624   4784216
# 32  11542510933377024  10715224
# 33   3092551473037312   4784216
# 34   4625556565917696  10715224
# 35    713065100214272    815960
# 36   1546275736518656   4784216
# 37    356505505234944    815960
# 38    178225707745280    815960
# 39   5771255466688512  10715224
# 40     89085809000448    815960
# 41     44515859628032    815960
# 42   2312778282958848  10715224
# 43       393996140544  10715224
# 44    773137868259328   4784216
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_chunked_512  \
# 0                                            0.505827
# 1                                            0.542107
# 2                                            0.512139
# 3                                            0.580189
# 4                                            0.544180
# 5                                            0.628157
# 6                                            0.554710
# 7                                            0.663137
# 8                                            0.634181
# 9                                            0.616713
# 10                                           0.696957
# 11                                           0.717186
# 12                                           0.702175
# 13                                           0.774465
# 14                                           0.795579
# 15                                           1.028403
# 16                                           1.031133
# 17                                           0.883159
# 18                                           0.872247
# 19                                           0.612282
# 20                                           1.148728
# 21                                           1.139486
# 22                                           1.302056
# 23                                           1.308450
# 24                                           1.528495
# 25                                           0.777817
# 26                                           0.997316
# 27                                           1.491033
# 28                                           1.841537
# 29                                           1.002739
# 30                                           1.869019
# 31                                           0.683746
# 32                                           0.599458
# 33                                           0.763294
# 34                                           0.681385
# 35                                           1.028272
# 36                                           0.875178
# 37                                           1.135678
# 38                                           1.308330
# 39                                           0.669744
# 40                                           1.531610
# 41                                           1.858666
# 42                                           0.764370
# 43                                           4.700279
# 44                                           1.001073
#
#     final_val_loss_ci_lower_MikiV_SimpleStories_SimpleStories_chunked_512  \
# 0                                            0.504502
# 1                                            0.540804
# 2                                            0.510749
# 3                                            0.578754
# 4                                            0.542756
# 5                                            0.626788
# 6                                            0.553260
# 7                                            0.661689
# 8                                            0.632686
# 9                                            0.615391
# 10                                           0.695586
# 11                                           0.715803
# 12                                           0.700650
# 13                                           0.773016
# 14                                           0.794197
# 15                                           1.026804
# 16                                           1.029413
# 17                                           0.881592
# 18                                           0.870680
# 19                                           0.610818
# 20                                           1.146701
# 21                                           1.137646
# 22                                           1.300322
# 23                                           1.306722
# 24                                           1.527055
# 25                                           0.776264
# 26                                           0.995721
# 27                                           1.489303
# 28                                           1.840410
# 29                                           1.001055
# 30                                           1.867968
# 31                                           0.682304
# 32                                           0.598049
# 33                                           0.761836
# 34                                           0.679803
# 35                                           1.026648
# 36                                           0.873729
# 37                                           1.133726
# 38                                           1.306729
# 39                                           0.668169
# 40                                           1.530249
# 41                                           1.857245
# 42                                           0.762770
# 43                                           4.699962
# 44                                           0.999346
#
#     final_val_loss_ci_upper_MikiV_SimpleStories_SimpleStories_chunked_512  \
# 0                                            0.507170
# 1                                            0.543472
# 2                                            0.513518
# 3                                            0.581654
# 4                                            0.545586
# 5                                            0.629734
# 6                                            0.556174
# 7                                            0.664672
# 8                                            0.635675
# 9                                            0.618175
# 10                                           0.698516
# 11                                           0.718706
# 12                                           0.703776
# 13                                           0.776247
# 14                                           0.797167
# 15                                           1.030205
# 16                                           1.033099
# 17                                           0.884911
# 18                                           0.874103
# 19                                           0.613777
# 20                                           1.150733
# 21                                           1.141404
# 22                                           1.304041
# 23                                           1.310257
# 24                                           1.530018
# 25                                           0.779445
# 26                                           0.999204
# 27                                           1.492755
# 28                                           1.842636
# 29                                           1.004637
# 30                                           1.870130
# 31                                           0.685432
# 32                                           0.600933
# 33                                           0.764935
# 34                                           0.682953
# 35                                           1.030049
# 36                                           0.876814
# 37                                           1.137831
# 38                                           1.310134
# 39                                           0.671317
# 40                                           1.533123
# 41                                           1.859943
# 42                                           0.766020
# 43                                           4.700596
# 44                                           1.003021
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_subchunked_256x2  \
# 0                                            0.548590
# 1                                            0.560333
# 2                                            0.545672
# 3                                            0.596018
# 4                                            0.584089
# 5                                            0.653030
# 6                                            0.583655
# 7                                            0.668744
# 8                                            0.649419
# 9                                            0.652348
# 10                                           0.717746
# 11                                           0.726584
# 12                                           0.713439
# 13                                           0.790500
# 14                                           0.806220
# 15                                           1.038981
# 16                                           1.037487
# 17                                           0.891919
# 18                                           0.884565
# 19                                           0.636904
# 20                                           1.155093
# 21                                           1.150131
# 22                                           1.308264
# 23                                           1.318747
# 24                                           1.533349
# 25                                           0.789396
# 26                                           1.005565
# 27                                           1.500281
# 28                                           1.844831
# 29                                           1.013687
# 30                                           1.873860
# 31                                           0.715510
# 32                                           0.635830
# 33                                           0.789249
# 34                                           0.702431
# 35                                           1.046522
# 36                                           0.896503
# 37                                           1.152560
# 38                                           1.323236
# 39                                           0.700905
# 40                                           1.545262
# 41                                           1.866384
# 42                                           0.780501
# 43                                           4.699548
# 44                                           1.020070
#
#     final_val_loss_ci_lower_MikiV_SimpleStories_SimpleStories_subchunked_256x2  \
# 0                                            0.547237
# 1                                            0.558996
# 2                                            0.544321
# 3                                            0.594639
# 4                                            0.582726
# 5                                            0.651572
# 6                                            0.582247
# 7                                            0.667243
# 8                                            0.647972
# 9                                            0.650898
# 10                                           0.716215
# 11                                           0.725102
# 12                                           0.711971
# 13                                           0.788775
# 14                                           0.804634
# 15                                           1.037129
# 16                                           1.035694
# 17                                           0.890200
# 18                                           0.882834
# 19                                           0.635496
# 20                                           1.153226
# 21                                           1.148282
# 22                                           1.306544
# 23                                           1.317058
# 24                                           1.531832
# 25                                           0.787888
# 26                                           1.003831
# 27                                           1.498692
# 28                                           1.843782
# 29                                           1.011888
# 30                                           1.872835
# 31                                           0.714052
# 32                                           0.634421
# 33                                           0.787662
# 34                                           0.700935
# 35                                           1.044687
# 36                                           0.894787
# 37                                           1.150621
# 38                                           1.321516
# 39                                           0.699446
# 40                                           1.543797
# 41                                           1.865235
# 42                                           0.778980
# 43                                           4.699184
# 44                                           1.018242
#
#     final_val_loss_ci_upper_MikiV_SimpleStories_SimpleStories_subchunked_256x2  \
# 0                                            0.549903
# 1                                            0.561611
# 2                                            0.546997
# 3                                            0.597388
# 4                                            0.585440
# 5                                            0.654653
# 6                                            0.585013
# 7                                            0.670381
# 8                                            0.650806
# 9                                            0.653936
# 10                                           0.719349
# 11                                           0.728222
# 12                                           0.714928
# 13                                           0.792211
# 14                                           0.807897
# 15                                           1.040858
# 16                                           1.039345
# 17                                           0.893695
# 18                                           0.886440
# 19                                           0.638336
# 20                                           1.157021
# 21                                           1.152135
# 22                                           1.310159
# 23                                           1.320454
# 24                                           1.534806
# 25                                           0.790902
# 26                                           1.007496
# 27                                           1.501915
# 28                                           1.845894
# 29                                           1.015549
# 30                                           1.874843
# 31                                           0.717075
# 32                                           0.637190
# 33                                           0.790913
# 34                                           0.703923
# 35                                           1.048426
# 36                                           0.898267
# 37                                           1.154523
# 38                                           1.325045
# 39                                           0.702324
# 40                                           1.546792
# 41                                           1.867511
# 42                                           0.782006
# 43                                           4.699908
# 44                                           1.021936
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_subchunked_128x4  \
# 0                                            0.612444
# 1                                            0.604004
# 2                                            0.602356
# 3                                            0.636429
# 4                                            0.644147
# 5                                            0.698473
# 6                                            0.635934
# 7                                            0.699285
# 8                                            0.684453
# 9                                            0.706715
# 10                                           0.757137
# 11                                           0.754748
# 12                                           0.743155
# 13                                           0.824170
# 14                                           0.830482
# 15                                           1.064224
# 16                                           1.054836
# 17                                           0.913640
# 18                                           0.914035
# 19                                           0.683625
# 20                                           1.170166
# 21                                           1.171866
# 22                                           1.321524
# 23                                           1.339174
# 24                                           1.543555
# 25                                           0.815182
# 26                                           1.024394
# 27                                           1.518362
# 28                                           1.851455
# 29                                           1.039796
# 30                                           1.883217
# 31                                           0.764928
# 32                                           0.690768
# 33                                           0.832928
# 34                                           0.742659
# 35                                           1.081052
# 36                                           0.934577
# 37                                           1.184691
# 38                                           1.351562
# 39                                           0.749772
# 40                                           1.570908
# 41                                           1.880922
# 42                                           0.813801
# 43                                           4.698370
# 44                                           1.055664
#
#     final_val_loss_ci_lower_MikiV_SimpleStories_SimpleStories_subchunked_128x4  \
# 0                                            0.611220
# 1                                            0.602794
# 2                                            0.601147
# 3                                            0.635187
# 4                                            0.642881
# 5                                            0.696954
# 6                                            0.634734
# 7                                            0.697805
# 8                                            0.683142
# 9                                            0.705225
# 10                                           0.755590
# 11                                           0.753192
# 12                                           0.741789
# 13                                           0.822545
# 14                                           0.828881
# 15                                           1.062483
# 16                                           1.053168
# 17                                           0.912047
# 18                                           0.912359
# 19                                           0.682331
# 20                                           1.168412
# 21                                           1.170114
# 22                                           1.319854
# 23                                           1.337581
# 24                                           1.542209
# 25                                           0.813772
# 26                                           1.022721
# 27                                           1.516952
# 28                                           1.850414
# 29                                           1.038147
# 30                                           1.882240
# 31                                           0.763408
# 32                                           0.689420
# 33                                           0.831304
# 34                                           0.741299
# 35                                           1.079291
# 36                                           0.932943
# 37                                           1.182992
# 38                                           1.349942
# 39                                           0.748416
# 40                                           1.569529
# 41                                           1.879870
# 42                                           0.812394
# 43                                           4.698055
# 44                                           1.053979
#
#     final_val_loss_ci_upper_MikiV_SimpleStories_SimpleStories_subchunked_128x4
# 0                                            0.613660
# 1                                            0.605257
# 2                                            0.603570
# 3                                            0.637671
# 4                                            0.645421
# 5                                            0.699936
# 6                                            0.637185
# 7                                            0.700779
# 8                                            0.685791
# 9                                            0.708270
# 10                                           0.758687
# 11                                           0.756282
# 12                                           0.744507
# 13                                           0.825791
# 14                                           0.832104
# 15                                           1.065947
# 16                                           1.056551
# 17                                           0.915253
# 18                                           0.915731
# 19                                           0.684908
# 20                                           1.171929
# 21                                           1.173605
# 22                                           1.323149
# 23                                           1.340741
# 24                                           1.544918
# 25                                           0.816617
# 26                                           1.026084
# 27                                           1.519737
# 28                                           1.852543
# 29                                           1.041553
# 30                                           1.884213
# 31                                           0.766433
# 32                                           0.692059
# 33                                           0.834520
# 34                                           0.744057
# 35                                           1.082815
# 36                                           0.936288
# 37                                           1.186406
# 38                                           1.353221
# 39                                           0.751127
# 40                                           1.572264
# 41                                           1.881964
# 42                                           0.815236
# 43                                           4.698687
# 44                                           1.057345

# %%
runs_df = runs_df[runs_df['run_name'].str.contains('256')]
val_loss_col = 'final_val_loss_MikiV_SimpleStories_SimpleStories_subchunked_256x2'

print("There are ", len(runs_df), " runs")
runs_df_finished = runs_df[runs_df['params'].notnull()]
print("There are ", len(runs_df_finished), " finished runs")

runs_df = runs_df_finished
runs_df = runs_df.astype(dtypes)
# Out:
# There are  15  runs
# There are  15  finished runs

# %%
import torch.nn as nn
class ScalingLaw(torch.nn.Module):
    """
    We model the loss as a function of number of parameters N and dataset size D as:
    $$
    \hat{L}(N, D) \triangleq E+\frac{A}{N^\alpha}+\frac{B}{D^\beta}
    $$
    """
    def __init__(self, a=0.0, b=0.0, e=0.0, alpha=0.5, beta=0.5):
        super().__init__()
        self.a = nn.Parameter(torch.tensor(a, dtype=torch.float32))
        self.b = nn.Parameter(torch.tensor(b, dtype=torch.float32))
        self.e = nn.Parameter(torch.tensor(e, dtype=torch.float32))
        self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32))
        self.beta = nn.Parameter(torch.tensor(beta, dtype=torch.float32))

    def forward(self, N, D):
        """
        N: tensor of model sizes (number of parameters)
        D: tensor of dataset sizes
        returns: predicted loss (same shape as N and D)
        """
        A = torch.exp(self.a)
        B = torch.exp(self.b)
        E = torch.exp(self.e)
        return E + A / (N ** self.alpha) + B / (D ** self.beta)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\h'
# <>:6: SyntaxWarning: invalid escape sequence '\h'
# /tmp/ipykernel_134240/280072866.py:6: SyntaxWarning: invalid escape sequence '\h'
#   \hat{L}(N, D) \triangleq E+\frac{A}{N^\alpha}+\frac{B}{D^\beta}

# %%
N = torch.tensor(pd.to_numeric(runs_df['params']).values, dtype=torch.float32)
D = torch.tensor(pd.to_numeric(runs_df['tokens_seen']).values, dtype=torch.float32)
L = torch.tensor(runs_df[val_loss_col].values, dtype=torch.float32)
X = torch.cat([N.unsqueeze(1), D.unsqueeze(1)], dim=1)
y = L

criterion = nn.HuberLoss(delta=1e-3)
total_epochs = 10000
learning_rate = 1e-3

# Containers for results
preds = torch.zeros_like(y)

models = []
for i in range(len(X)):
    print(f"LOOCV: leaving out sample {i+1}/{len(X)}")

    # Split train/val
    train_mask = torch.ones(len(X), dtype=bool)

    train_mask[i] = False

    X_train, y_train = X[train_mask], y[train_mask]
    X_val, y_val = X[~train_mask], y[~train_mask]

    # Initialize new model for each fold
    model = ScalingLaw()
    optimizer = optim.AdamW(model.parameters(), lr=1e-2, weight_decay=1e-9)
    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=total_epochs)

    # --- Train ---
    for epoch in range(total_epochs):
        model.train()
        optimizer.zero_grad()
        L_pred = model(X_train[:, 0], X_train[:, 1])
        loss = criterion(torch.log(L_pred), torch.log(y_train))
        loss.backward()
        optimizer.step()
        lr_scheduler.step()

    # --- Predict on left-out sample ---
    model.eval()
    with torch.no_grad():
        pred = model(X_val[:, 0], X_val[:, 1])
        preds[i] = pred
    models.append(model)

# Write results back to the dataframe
runs_df['pred'] = preds.detach().numpy().flatten()
runs_df['error_abs'] = (runs_df['pred'] - runs_df[val_loss_col]).abs()
runs_df['error_rel'] = runs_df['error_abs'] / runs_df[val_loss_col]

# Show results sorted by largest absolute error
result_df = runs_df[['run_name', val_loss_col, 'pred', 'error_abs', 'error_rel']] \
    .sort_values(by='error_abs', ascending=False)
result_df
# Out:
# LOOCV: leaving out sample 1/15
# LOOCV: leaving out sample 2/15
# LOOCV: leaving out sample 3/15
# LOOCV: leaving out sample 4/15
# LOOCV: leaving out sample 5/15
# LOOCV: leaving out sample 6/15
# LOOCV: leaving out sample 7/15
# LOOCV: leaving out sample 8/15
# LOOCV: leaving out sample 9/15
# LOOCV: leaving out sample 10/15
# LOOCV: leaving out sample 11/15
# LOOCV: leaving out sample 12/15
# LOOCV: leaving out sample 13/15
# LOOCV: leaving out sample 14/15
# LOOCV: leaving out sample 15/15
#                                       run_name  \
# 30   cfgs/simple_stories_chartok/256/2M/1.yaml
# 27   cfgs/simple_stories_chartok/256/2M/2.yaml
# 15   cfgs/simple_stories_chartok/256/2M/5.yaml
# 23   cfgs/simple_stories_chartok/256/2M/3.yaml
# 21   cfgs/simple_stories_chartok/256/2M/4.yaml
# 42  cfgs/simple_stories_chartok/256/14M/1.yaml
# 2   cfgs/simple_stories_chartok/256/14M/5.yaml
# 34  cfgs/simple_stories_chartok/256/14M/2.yaml
# 6   cfgs/simple_stories_chartok/256/14M/4.yaml
# 29   cfgs/simple_stories_chartok/256/7M/1.yaml
# 18   cfgs/simple_stories_chartok/256/7M/2.yaml
# 5    cfgs/simple_stories_chartok/256/7M/5.yaml
# 10   cfgs/simple_stories_chartok/256/7M/4.yaml
# 19  cfgs/simple_stories_chartok/256/14M/3.yaml
# 13   cfgs/simple_stories_chartok/256/7M/3.yaml
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_subchunked_256x2  \
# 30                                           1.873860
# 27                                           1.500281
# 15                                           1.038981
# 23                                           1.318747
# 21                                           1.150131
# 42                                           0.780501
# 2                                            0.545672
# 34                                           0.702431
# 6                                            0.583655
# 29                                           1.013687
# 18                                           0.884565
# 5                                            0.653030
# 10                                           0.717746
# 19                                           0.636904
# 13                                           0.790500
#
#         pred  error_abs  error_rel
# 30  1.605595   0.268265   0.143162
# 27  1.422703   0.077578   0.051709
# 15  1.098547   0.059566   0.057332
# 23  1.276790   0.041957   0.031816
# 21  1.191557   0.041426   0.036019
# 42  0.812501   0.032000   0.041000
# 2   0.520619   0.025052   0.045911
# 34  0.714445   0.012014   0.017103
# 6   0.571756   0.011899   0.020386
# 29  1.002317   0.011370   0.011216
# 18  0.891314   0.006749   0.007630
# 5   0.659034   0.006004   0.009194
# 10  0.713498   0.004248   0.005919
# 19  0.633296   0.003609   0.005666
# 13  0.793645   0.003145   0.003979

# %%
from math import exp
As = np.array([exp(m.a.item()) for m in models])
Bs = np.array([exp(m.b.item()) for m in models])
Es = np.array([exp(m.e.item()) for m in models])
alphas = np.array([m.alpha.item() for m in models])
betas = np.array([m.beta.item() for m in models])

# Boxplots of the parameters
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
axs[0, 0].boxplot(As)
axs[0, 0].set_title('A values')
axs[0, 1].boxplot(Bs)
axs[0, 1].set_title('B values')
axs[0, 2].boxplot(Es)
axs[0, 2].set_title('E values')
axs[1, 0].boxplot(alphas)
axs[1, 0].set_title('alpha values')
axs[1, 1].boxplot(betas)
axs[1, 1].set_title('beta values')
plt.tight_layout()
plt.show()

# %%
 
total_epochs = 20000
model = ScalingLaw()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=total_epochs)
for epoch in range(total_epochs):
    model.train()
    optimizer.zero_grad()
    L_pred = model(N, D)
    loss = criterion(torch.log(L_pred), torch.log(L))
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.0003202329098712653
# Epoch 100, Loss: 0.0002995409886352718
# Epoch 200, Loss: 0.0002823676622938365
# Epoch 300, Loss: 0.0002716065209824592
# Epoch 400, Loss: 0.00026301463367417455
# Epoch 500, Loss: 0.0002551353245507926
# Epoch 600, Loss: 0.0002474116045050323
# Epoch 700, Loss: 0.00023935064382385463
# Epoch 800, Loss: 0.00023073436750564724
# Epoch 900, Loss: 0.00022191893367562443
# Epoch 1000, Loss: 0.00021329931041691452
# Epoch 1100, Loss: 0.00020522184786386788
# Epoch 1200, Loss: 0.0001972187019418925
# Epoch 1300, Loss: 0.0001898295449791476
# Epoch 1400, Loss: 0.00018262250523548573
# Epoch 1500, Loss: 0.00017553436919115484
# Epoch 1600, Loss: 0.0001684711460256949
# Epoch 1700, Loss: 0.0001613518688827753
# Epoch 1800, Loss: 0.00015418125258293003
# Epoch 1900, Loss: 0.00014731731789652258
# Epoch 2000, Loss: 0.0001404865033691749
# Epoch 2100, Loss: 0.00013378298899624497
# Epoch 2200, Loss: 0.00012728554429486394
# Epoch 2300, Loss: 0.00012081757449777797
# Epoch 2400, Loss: 0.00011447028373368084
# Epoch 2500, Loss: 0.0001082807793864049
# Epoch 2600, Loss: 0.00010225123696727678
# Epoch 2700, Loss: 9.624432277632877e-05
# Epoch 2800, Loss: 9.04848420759663e-05
# Epoch 2900, Loss: 8.47668488859199e-05
# Epoch 3000, Loss: 7.934283348731697e-05
# Epoch 3100, Loss: 7.406031363643706e-05
# Epoch 3200, Loss: 6.932185351615772e-05
# Epoch 3300, Loss: 6.533494888572022e-05
# Epoch 3400, Loss: 6.145225052023306e-05
# Epoch 3500, Loss: 5.752556899096817e-05
# Epoch 3600, Loss: 5.354375025490299e-05
# Epoch 3700, Loss: 4.955163240083493e-05
# Epoch 3800, Loss: 4.623902350431308e-05
# Epoch 3900, Loss: 4.268864358891733e-05
# Epoch 4000, Loss: 4.02886034862604e-05
# Epoch 4100, Loss: 3.850647044600919e-05
# Epoch 4200, Loss: 3.6855850339634344e-05
# Epoch 4300, Loss: 3.518156154314056e-05
# Epoch 4400, Loss: 3.346565426909365e-05
# Epoch 4500, Loss: 3.178147380822338e-05
# Epoch 4600, Loss: 3.0480272471322678e-05
# Epoch 4700, Loss: 2.976569339807611e-05
# Epoch 4800, Loss: 2.929623042291496e-05
# Epoch 4900, Loss: 2.9150143745937385e-05
# Epoch 5000, Loss: 2.9004373573116027e-05
# Epoch 5100, Loss: 2.8853046387666836e-05
# Epoch 5200, Loss: 2.8696025765384547e-05
# Epoch 5300, Loss: 2.8533182558021508e-05
# Epoch 5400, Loss: 2.836439489328768e-05
# Epoch 5500, Loss: 2.818951543304138e-05
# Epoch 5600, Loss: 2.800838410621509e-05
# Epoch 5700, Loss: 2.782093179121148e-05
# Epoch 5800, Loss: 2.7626962037174962e-05
# Epoch 5900, Loss: 2.755199238890782e-05
# Epoch 6000, Loss: 2.7241123461863026e-05
# Epoch 6100, Loss: 2.7049854907090776e-05
# Epoch 6200, Loss: 2.686432344489731e-05
# Epoch 6300, Loss: 2.6667101337807253e-05
# Epoch 6400, Loss: 2.7445981686469167e-05
# Epoch 6500, Loss: 2.6528470698394813e-05
# Epoch 6600, Loss: 2.635497548908461e-05
# Epoch 6700, Loss: 2.627079993544612e-05
# Epoch 6800, Loss: 2.616435995150823e-05
# Epoch 6900, Loss: 2.610138471936807e-05
# Epoch 7000, Loss: 2.6035735572804697e-05
# Epoch 7100, Loss: 2.596740159788169e-05
# Epoch 7200, Loss: 2.589622999948915e-05
# Epoch 7300, Loss: 2.582213892310392e-05
# Epoch 7400, Loss: 2.5744982849573717e-05
# Epoch 7500, Loss: 2.5664767235866748e-05
# Epoch 7600, Loss: 2.5581270165275782e-05
# Epoch 7700, Loss: 2.5494788133073598e-05
# Epoch 7800, Loss: 2.541971844038926e-05
# Epoch 7900, Loss: 2.533788574510254e-05
# Epoch 8000, Loss: 2.5259463654947467e-05
# Epoch 8100, Loss: 2.5201770768035203e-05
# Epoch 8200, Loss: 2.514801235520281e-05
# Epoch 8300, Loss: 2.5100016500800848e-05
# Epoch 8400, Loss: 2.504887743270956e-05
# Epoch 8500, Loss: 2.5003153496072628e-05
# Epoch 8600, Loss: 2.4957891582744196e-05
# Epoch 8700, Loss: 2.491227860446088e-05
# Epoch 8800, Loss: 2.4866187231964432e-05
# Epoch 8900, Loss: 2.481941737642046e-05
# Epoch 9000, Loss: 2.4771738026174717e-05
# Epoch 9100, Loss: 2.4723232854739763e-05
# Epoch 9200, Loss: 2.4673679945408367e-05
# Epoch 9300, Loss: 2.4622702767373994e-05
# Epoch 9400, Loss: 2.4569635570514947e-05
# Epoch 9500, Loss: 2.451617365295533e-05
# Epoch 9600, Loss: 2.4460558051941916e-05
# Epoch 9700, Loss: 2.4402737835771404e-05
# Epoch 9800, Loss: 2.434263842587825e-05
# Epoch 9900, Loss: 2.4282206140924245e-05
# Epoch 10000, Loss: 2.4221437342930585e-05
# Epoch 10100, Loss: 2.4162241970770992e-05
# Epoch 10200, Loss: 2.409687112958636e-05
# Epoch 10300, Loss: 2.403495273028966e-05
# Epoch 10400, Loss: 2.3971339032868855e-05
# Epoch 10500, Loss: 2.3909293304313906e-05
# Epoch 10600, Loss: 2.3850920115364715e-05
# Epoch 10700, Loss: 2.3795997549314052e-05
# Epoch 10800, Loss: 2.3738015443086624e-05
# Epoch 10900, Loss: 2.3686250642640516e-05
# Epoch 11000, Loss: 2.362537634326145e-05
# Epoch 11100, Loss: 2.357451739953831e-05
# Epoch 11200, Loss: 2.3524062271462753e-05
# Epoch 11300, Loss: 2.347438203287311e-05
# Epoch 11400, Loss: 2.3425645849783905e-05
# Epoch 11500, Loss: 2.337827390874736e-05
# Epoch 11600, Loss: 2.332819531147834e-05
# Epoch 11700, Loss: 2.3280437744688243e-05
# Epoch 11800, Loss: 2.323363696632441e-05
# Epoch 11900, Loss: 2.318586666660849e-05
# Epoch 12000, Loss: 2.313835284439847e-05
# Epoch 12100, Loss: 2.309051706106402e-05
# Epoch 12200, Loss: 2.304265035490971e-05
# Epoch 12300, Loss: 2.299438347108662e-05
# Epoch 12400, Loss: 2.2945509044802748e-05
# Epoch 12500, Loss: 2.2895927031640895e-05
# Epoch 12600, Loss: 2.2845459170639515e-05
# Epoch 12700, Loss: 2.279407090099994e-05
# Epoch 12800, Loss: 2.2741523935110308e-05
# Epoch 12900, Loss: 2.2687750970362686e-05
# Epoch 13000, Loss: 2.2632690161117353e-05
# Epoch 13100, Loss: 2.2576348783331923e-05
# Epoch 13200, Loss: 2.2518777768709697e-05
# Epoch 13300, Loss: 2.2459988031187095e-05
# Epoch 13400, Loss: 2.2400055968319066e-05
# Epoch 13500, Loss: 2.2339036149787717e-05
# Epoch 13600, Loss: 2.2278109099715948e-05
# Epoch 13700, Loss: 2.221695649495814e-05
# Epoch 13800, Loss: 2.2155834813020192e-05
# Epoch 13900, Loss: 2.209531157859601e-05
# Epoch 14000, Loss: 2.2034879293642007e-05
# Epoch 14100, Loss: 2.1974074115860276e-05
# Epoch 14200, Loss: 2.191395833506249e-05
# Epoch 14300, Loss: 2.1854140868526883e-05
# Epoch 14400, Loss: 2.1795462089357898e-05
# Epoch 14500, Loss: 2.173507346014958e-05
# Epoch 14600, Loss: 2.1676112737623043e-05
# Epoch 14700, Loss: 2.1617119273287244e-05
# Epoch 14800, Loss: 2.1558746084338054e-05
# Epoch 14900, Loss: 2.150098589481786e-05
# Epoch 15000, Loss: 2.1443856894620694e-05
# Epoch 15100, Loss: 2.138695344910957e-05
# Epoch 15200, Loss: 2.1331019524950534e-05
# Epoch 15300, Loss: 2.127610241586808e-05
# Epoch 15400, Loss: 2.1221856513875537e-05
# Epoch 15500, Loss: 2.1168309103813954e-05
# Epoch 15600, Loss: 2.1115654817549512e-05
# Epoch 15700, Loss: 2.1064035536255687e-05
# Epoch 15800, Loss: 2.1013511286582798e-05
# Epoch 15900, Loss: 2.096418756991625e-05
# Epoch 16000, Loss: 2.0916097128065303e-05
# Epoch 16100, Loss: 2.0869350919383578e-05
# Epoch 16200, Loss: 2.082405444525648e-05
# Epoch 16300, Loss: 2.078026045637671e-05
# Epoch 16400, Loss: 2.0738008970511146e-05
# Epoch 16500, Loss: 2.0697360014310107e-05
# Epoch 16600, Loss: 2.065838452836033e-05
# Epoch 16700, Loss: 2.0621127987396903e-05
# Epoch 16800, Loss: 2.0585597667377442e-05
# Epoch 16900, Loss: 2.0551820853143e-05
# Epoch 17000, Loss: 2.05198102776194e-05
# Epoch 17100, Loss: 2.0489531380007975e-05
# Epoch 17200, Loss: 2.0461033273022622e-05
# Epoch 17300, Loss: 2.0434245016076602e-05
# Epoch 17400, Loss: 2.0409164790180512e-05
# Epoch 17500, Loss: 2.0385790776344948e-05
# Epoch 17600, Loss: 2.036406112893019e-05
# Epoch 17700, Loss: 2.0344048607512377e-05
# Epoch 17800, Loss: 2.0325702280388214e-05
# Epoch 17900, Loss: 2.0308927560108714e-05
# Epoch 18000, Loss: 2.029361712629907e-05
# Epoch 18100, Loss: 2.0279758246033452e-05
# Epoch 18200, Loss: 2.0267241779947653e-05
# Epoch 18300, Loss: 2.025604226219002e-05
# Epoch 18400, Loss: 2.024605419137515e-05
# Epoch 18500, Loss: 2.0237212083884515e-05
# Epoch 18600, Loss: 2.0229461370036006e-05
# Epoch 18700, Loss: 2.022272747126408e-05
# Epoch 18800, Loss: 2.0216939446981996e-05
# Epoch 18900, Loss: 2.0212029994581826e-05
# Epoch 19000, Loss: 2.0207935449434444e-05
# Epoch 19100, Loss: 2.020455212914385e-05
# Epoch 19200, Loss: 2.02018600248266e-05
# Epoch 19300, Loss: 2.0199744540150277e-05
# Epoch 19400, Loss: 2.019815110543277e-05
# Epoch 19500, Loss: 2.019703242694959e-05
# Epoch 19600, Loss: 2.019626299443189e-05
# Epoch 19700, Loss: 2.0195799152133986e-05
# Epoch 19800, Loss: 2.019550811382942e-05
# Epoch 19900, Loss: 2.0195495380903594e-05

# %%
preds = model(N, D)
runs_df['pred'] = preds.detach().numpy().flatten()
runs_df['error_abs'] = (runs_df['pred'] - runs_df[val_loss_col]).abs()
runs_df['error_rel'] = runs_df['error_abs'] / runs_df[val_loss_col]
runs_df[['run_name', val_loss_col, 'pred', 'error_abs', 'error_rel']].sort_values(by='error_abs', ascending=False)
# Out:
#                                       run_name  \
# 30   cfgs/simple_stories_chartok/256/2M/1.yaml
# 15   cfgs/simple_stories_chartok/256/2M/5.yaml
# 21   cfgs/simple_stories_chartok/256/2M/4.yaml
# 42  cfgs/simple_stories_chartok/256/14M/1.yaml
# 27   cfgs/simple_stories_chartok/256/2M/2.yaml
# 2   cfgs/simple_stories_chartok/256/14M/5.yaml
# 34  cfgs/simple_stories_chartok/256/14M/2.yaml
# 6   cfgs/simple_stories_chartok/256/14M/4.yaml
# 23   cfgs/simple_stories_chartok/256/2M/3.yaml
# 18   cfgs/simple_stories_chartok/256/7M/2.yaml
# 10   cfgs/simple_stories_chartok/256/7M/4.yaml
# 13   cfgs/simple_stories_chartok/256/7M/3.yaml
# 29   cfgs/simple_stories_chartok/256/7M/1.yaml
# 5    cfgs/simple_stories_chartok/256/7M/5.yaml
# 19  cfgs/simple_stories_chartok/256/14M/3.yaml
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_subchunked_256x2  \
# 30                                           1.873860
# 15                                           1.038981
# 21                                           1.150131
# 42                                           0.780501
# 27                                           1.500281
# 2                                            0.545672
# 34                                           0.702431
# 6                                            0.583655
# 23                                           1.318747
# 18                                           0.884565
# 10                                           0.717746
# 13                                           0.790500
# 29                                           1.013687
# 5                                            0.653030
# 19                                           0.636904
#
#         pred  error_abs  error_rel
# 30  1.683120   0.190740   0.101790
# 15  1.081374   0.042393   0.040803
# 21  1.182786   0.032655   0.028392
# 42  0.811642   0.031141   0.039898
# 27  1.475211   0.025070   0.016710
# 2   0.528482   0.017190   0.031502
# 34  0.713860   0.011429   0.016271
# 6   0.576227   0.007428   0.012726
# 23  1.311590   0.007157   0.005427
# 18  0.888926   0.004361   0.004930
# 10  0.714145   0.003600   0.005016
# 13  0.791144   0.000644   0.000815
# 29  1.013102   0.000585   0.000577
# 5   0.653512   0.000481   0.000737
# 19  0.636861   0.000043   0.000068

# %%
A = torch.exp(model.a).item()
B = torch.exp(model.b).item()
E = torch.exp(model.e).item()
alpha = model.alpha.item()
beta = model.beta.item()
print(f"A={A}, B={B}, E={E}, alpha={alpha}, beta={beta}")
# Out:
# A=88.68563079833984, B=356.2739562988281, E=0.129253089427948, alpha=0.3699607849121094, beta=0.34473952651023865
