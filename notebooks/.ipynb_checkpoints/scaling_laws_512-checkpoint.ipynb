# %%
import wandb
import pandas as pd

import torch
import torch.optim as optim
import numpy as np

# %%
entity="miki-and-tml"
project="scaling-tests"
api = wandb.Api()

runs = api.runs(f"{entity}/{project}")

datasets = ['MikiV_SimpleStories_SimpleStories_chunked_512', 'MikiV_SimpleStories_SimpleStories_subchunked_256x2',  'MikiV_SimpleStories_SimpleStories_subchunked_128x4']

val_cols = [f'final_val_loss{ci_suffix}_{dataset}' for dataset in datasets for ci_suffix in ['', '_ci_lower', '_ci_upper']]
dtypes = {
    'run_id': str, # or 'object'
    'tokens_seen': int, # or 'int64'
    'compute': float,
    'params': int
} 
dtypes.update({col: float for col in val_cols})

# 2. Create the empty DataFrame, using keys from dtypes as columns
runs_df = pd.DataFrame(columns=dtypes.keys())

for run in runs:
    summary = run.summary._json_dict
    
    # Extract final logged values, defaulting to None if not available
    row = {
        'run_id': run.id,
        'run_name': run.name,
    }
    row.update({col: summary.get(col) for col in dtypes.keys()})
    runs_df = pd.concat([pd.DataFrame([row]), runs_df]).reset_index(drop=True)

runs_df
# Out:
# wandb: Currently logged in as: vanousekmikulas (vanousekmikulas-epfl) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# /tmp/ipykernel_134041/2836687964.py:30: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   runs_df = pd.concat([pd.DataFrame([row]), runs_df]).reset_index(drop=True)
#    run_id                                    run_name tokens_seen  \
# 0    None  cfgs/simple_stories_chartok/512/14M/5.yaml  3839983616
# 1    None  cfgs/simple_stories_chartok/128/14M/5.yaml  3839983616
# 2    None  cfgs/simple_stories_chartok/256/14M/5.yaml  3839983616
# 3    None  cfgs/simple_stories_chartok/128/14M/4.yaml  1919975424
# 4    None  cfgs/simple_stories_chartok/512/14M/4.yaml  1919975424
# 5    None   cfgs/simple_stories_chartok/256/7M/5.yaml  1919975424
# 6    None  cfgs/simple_stories_chartok/256/14M/4.yaml  1919975424
# 7    None   cfgs/simple_stories_chartok/128/7M/5.yaml  1919975424
# 8    None  cfgs/simple_stories_chartok/128/14M/3.yaml   959971328
# 9    None   cfgs/simple_stories_chartok/512/7M/5.yaml  1919975424
# 10   None   cfgs/simple_stories_chartok/256/7M/4.yaml   959971328
# 11   None   cfgs/simple_stories_chartok/128/7M/4.yaml   959971328
# 12   None  cfgs/simple_stories_chartok/128/14M/2.yaml   479985664
# 13   None   cfgs/simple_stories_chartok/256/7M/3.yaml   479985664
# 14   None   cfgs/simple_stories_chartok/128/7M/3.yaml   479985664
# 15   None   cfgs/simple_stories_chartok/256/2M/5.yaml   431980544
# 16   None   cfgs/simple_stories_chartok/128/2M/5.yaml   431980544
# 17   None   cfgs/simple_stories_chartok/128/7M/2.yaml   239992832
# 18   None   cfgs/simple_stories_chartok/256/7M/2.yaml   239992832
# 19   None  cfgs/simple_stories_chartok/256/14M/3.yaml   959971328
# 20   None   cfgs/simple_stories_chartok/128/2M/4.yaml   215973888
# 21   None   cfgs/simple_stories_chartok/256/2M/4.yaml   215973888
# 22   None   cfgs/simple_stories_chartok/128/2M/3.yaml   107970560
# 23   None   cfgs/simple_stories_chartok/256/2M/3.yaml   107970560
# 24   None   cfgs/simple_stories_chartok/128/2M/2.yaml    53968896
# 25   None  cfgs/simple_stories_chartok/128/14M/1.yaml   239992832
# 26   None   cfgs/simple_stories_chartok/128/7M/1.yaml   119996416
# 27   None   cfgs/simple_stories_chartok/256/2M/2.yaml    53968896
# 28   None   cfgs/simple_stories_chartok/128/2M/1.yaml    26968064
# 29   None   cfgs/simple_stories_chartok/256/7M/1.yaml   119996416
# 30   None   cfgs/simple_stories_chartok/256/2M/1.yaml    26968064
# 31   None   cfgs/simple_stories_chartok/512/7M/4.yaml   959971328
# 32   None  cfgs/simple_stories_chartok/512/14M/3.yaml   959971328
# 33   None   cfgs/simple_stories_chartok/512/7M/3.yaml   479985664
# 34   None  cfgs/simple_stories_chartok/256/14M/2.yaml   479985664
# 35   None   cfgs/simple_stories_chartok/512/2M/5.yaml   431980544
# 36   None   cfgs/simple_stories_chartok/512/7M/2.yaml   239992832
# 37   None   cfgs/simple_stories_chartok/512/2M/4.yaml   215973888
# 38   None   cfgs/simple_stories_chartok/512/2M/3.yaml   107970560
# 39   None  cfgs/simple_stories_chartok/512/14M/2.yaml   479985664
# 40   None   cfgs/simple_stories_chartok/512/2M/2.yaml    53968896
# 41   None   cfgs/simple_stories_chartok/512/2M/1.yaml    26968064
# 42   None  cfgs/simple_stories_chartok/256/14M/1.yaml   239992832
# 43   None  cfgs/simple_stories_chartok/512/14M/1.yaml       32768
# 44   None   cfgs/simple_stories_chartok/512/7M/1.yaml   119996416
#
#               compute    params  \
# 0   46171225721929730  10715224
# 1   32422486943465470  10715224
# 2   37005399869620220  10715224
# 3   16211105135198208  10715224
# 4   23085415862894590  10715224
# 5    9315167804325888   4784216
# 6   18502542044430336  10715224
# 7    7787543198171136   4784216
# 8    8105414231064576  10715224
# 9   12370417016635392   4784216
# 10   4657504411713536   4784216
# 11   3893705144532992   4784216
# 12   4052707115532288  10715224
# 13   2328752205856768   4784216
# 14   1946852572266496   4784216
# 15    481274707836928    815960
# 16    365379511648256    815960
# 17    973426286133248   4784216
# 18   1164376102928384   4784216
# 19   9251113131835392  10715224
# 20    182675897843712    815960
# 21    240619100307456    815960
# 22     91324090941440    815960
# 23    120291296542720    815960
# 24     45648187490304    815960
# 25   2026353557766144  10715224
# 26    486713143066624   4784216
# 27     60127394660352    815960
# 28     22810235764736    815960
# 29    582188051464192   4784216
# 30     30045443719168    815960
# 31   6185102946074624   4784216
# 32  11542510933377024  10715224
# 33   3092551473037312   4784216
# 34   4625556565917696  10715224
# 35    713065100214272    815960
# 36   1546275736518656   4784216
# 37    356505505234944    815960
# 38    178225707745280    815960
# 39   5771255466688512  10715224
# 40     89085809000448    815960
# 41     44515859628032    815960
# 42   2312778282958848  10715224
# 43       393996140544  10715224
# 44    773137868259328   4784216
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_chunked_512  \
# 0                                            0.505827
# 1                                            0.542107
# 2                                            0.512139
# 3                                            0.580189
# 4                                            0.544180
# 5                                            0.628157
# 6                                            0.554710
# 7                                            0.663137
# 8                                            0.634181
# 9                                            0.616713
# 10                                           0.696957
# 11                                           0.717186
# 12                                           0.702175
# 13                                           0.774465
# 14                                           0.795579
# 15                                           1.028403
# 16                                           1.031133
# 17                                           0.883159
# 18                                           0.872247
# 19                                           0.612282
# 20                                           1.148728
# 21                                           1.139486
# 22                                           1.302056
# 23                                           1.308450
# 24                                           1.528495
# 25                                           0.777817
# 26                                           0.997316
# 27                                           1.491033
# 28                                           1.841537
# 29                                           1.002739
# 30                                           1.869019
# 31                                           0.683746
# 32                                           0.599458
# 33                                           0.763294
# 34                                           0.681385
# 35                                           1.028272
# 36                                           0.875178
# 37                                           1.135678
# 38                                           1.308330
# 39                                           0.669744
# 40                                           1.531610
# 41                                           1.858666
# 42                                           0.764370
# 43                                           4.700279
# 44                                           1.001073
#
#     final_val_loss_ci_lower_MikiV_SimpleStories_SimpleStories_chunked_512  \
# 0                                            0.504502
# 1                                            0.540804
# 2                                            0.510749
# 3                                            0.578754
# 4                                            0.542756
# 5                                            0.626788
# 6                                            0.553260
# 7                                            0.661689
# 8                                            0.632686
# 9                                            0.615391
# 10                                           0.695586
# 11                                           0.715803
# 12                                           0.700650
# 13                                           0.773016
# 14                                           0.794197
# 15                                           1.026804
# 16                                           1.029413
# 17                                           0.881592
# 18                                           0.870680
# 19                                           0.610818
# 20                                           1.146701
# 21                                           1.137646
# 22                                           1.300322
# 23                                           1.306722
# 24                                           1.527055
# 25                                           0.776264
# 26                                           0.995721
# 27                                           1.489303
# 28                                           1.840410
# 29                                           1.001055
# 30                                           1.867968
# 31                                           0.682304
# 32                                           0.598049
# 33                                           0.761836
# 34                                           0.679803
# 35                                           1.026648
# 36                                           0.873729
# 37                                           1.133726
# 38                                           1.306729
# 39                                           0.668169
# 40                                           1.530249
# 41                                           1.857245
# 42                                           0.762770
# 43                                           4.699962
# 44                                           0.999346
#
#     final_val_loss_ci_upper_MikiV_SimpleStories_SimpleStories_chunked_512  \
# 0                                            0.507170
# 1                                            0.543472
# 2                                            0.513518
# 3                                            0.581654
# 4                                            0.545586
# 5                                            0.629734
# 6                                            0.556174
# 7                                            0.664672
# 8                                            0.635675
# 9                                            0.618175
# 10                                           0.698516
# 11                                           0.718706
# 12                                           0.703776
# 13                                           0.776247
# 14                                           0.797167
# 15                                           1.030205
# 16                                           1.033099
# 17                                           0.884911
# 18                                           0.874103
# 19                                           0.613777
# 20                                           1.150733
# 21                                           1.141404
# 22                                           1.304041
# 23                                           1.310257
# 24                                           1.530018
# 25                                           0.779445
# 26                                           0.999204
# 27                                           1.492755
# 28                                           1.842636
# 29                                           1.004637
# 30                                           1.870130
# 31                                           0.685432
# 32                                           0.600933
# 33                                           0.764935
# 34                                           0.682953
# 35                                           1.030049
# 36                                           0.876814
# 37                                           1.137831
# 38                                           1.310134
# 39                                           0.671317
# 40                                           1.533123
# 41                                           1.859943
# 42                                           0.766020
# 43                                           4.700596
# 44                                           1.003021
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_subchunked_256x2  \
# 0                                            0.548590
# 1                                            0.560333
# 2                                            0.545672
# 3                                            0.596018
# 4                                            0.584089
# 5                                            0.653030
# 6                                            0.583655
# 7                                            0.668744
# 8                                            0.649419
# 9                                            0.652348
# 10                                           0.717746
# 11                                           0.726584
# 12                                           0.713439
# 13                                           0.790500
# 14                                           0.806220
# 15                                           1.038981
# 16                                           1.037487
# 17                                           0.891919
# 18                                           0.884565
# 19                                           0.636904
# 20                                           1.155093
# 21                                           1.150131
# 22                                           1.308264
# 23                                           1.318747
# 24                                           1.533349
# 25                                           0.789396
# 26                                           1.005565
# 27                                           1.500281
# 28                                           1.844831
# 29                                           1.013687
# 30                                           1.873860
# 31                                           0.715510
# 32                                           0.635830
# 33                                           0.789249
# 34                                           0.702431
# 35                                           1.046522
# 36                                           0.896503
# 37                                           1.152560
# 38                                           1.323236
# 39                                           0.700905
# 40                                           1.545262
# 41                                           1.866384
# 42                                           0.780501
# 43                                           4.699548
# 44                                           1.020070
#
#     final_val_loss_ci_lower_MikiV_SimpleStories_SimpleStories_subchunked_256x2  \
# 0                                            0.547237
# 1                                            0.558996
# 2                                            0.544321
# 3                                            0.594639
# 4                                            0.582726
# 5                                            0.651572
# 6                                            0.582247
# 7                                            0.667243
# 8                                            0.647972
# 9                                            0.650898
# 10                                           0.716215
# 11                                           0.725102
# 12                                           0.711971
# 13                                           0.788775
# 14                                           0.804634
# 15                                           1.037129
# 16                                           1.035694
# 17                                           0.890200
# 18                                           0.882834
# 19                                           0.635496
# 20                                           1.153226
# 21                                           1.148282
# 22                                           1.306544
# 23                                           1.317058
# 24                                           1.531832
# 25                                           0.787888
# 26                                           1.003831
# 27                                           1.498692
# 28                                           1.843782
# 29                                           1.011888
# 30                                           1.872835
# 31                                           0.714052
# 32                                           0.634421
# 33                                           0.787662
# 34                                           0.700935
# 35                                           1.044687
# 36                                           0.894787
# 37                                           1.150621
# 38                                           1.321516
# 39                                           0.699446
# 40                                           1.543797
# 41                                           1.865235
# 42                                           0.778980
# 43                                           4.699184
# 44                                           1.018242
#
#     final_val_loss_ci_upper_MikiV_SimpleStories_SimpleStories_subchunked_256x2  \
# 0                                            0.549903
# 1                                            0.561611
# 2                                            0.546997
# 3                                            0.597388
# 4                                            0.585440
# 5                                            0.654653
# 6                                            0.585013
# 7                                            0.670381
# 8                                            0.650806
# 9                                            0.653936
# 10                                           0.719349
# 11                                           0.728222
# 12                                           0.714928
# 13                                           0.792211
# 14                                           0.807897
# 15                                           1.040858
# 16                                           1.039345
# 17                                           0.893695
# 18                                           0.886440
# 19                                           0.638336
# 20                                           1.157021
# 21                                           1.152135
# 22                                           1.310159
# 23                                           1.320454
# 24                                           1.534806
# 25                                           0.790902
# 26                                           1.007496
# 27                                           1.501915
# 28                                           1.845894
# 29                                           1.015549
# 30                                           1.874843
# 31                                           0.717075
# 32                                           0.637190
# 33                                           0.790913
# 34                                           0.703923
# 35                                           1.048426
# 36                                           0.898267
# 37                                           1.154523
# 38                                           1.325045
# 39                                           0.702324
# 40                                           1.546792
# 41                                           1.867511
# 42                                           0.782006
# 43                                           4.699908
# 44                                           1.021936
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_subchunked_128x4  \
# 0                                            0.612444
# 1                                            0.604004
# 2                                            0.602356
# 3                                            0.636429
# 4                                            0.644147
# 5                                            0.698473
# 6                                            0.635934
# 7                                            0.699285
# 8                                            0.684453
# 9                                            0.706715
# 10                                           0.757137
# 11                                           0.754748
# 12                                           0.743155
# 13                                           0.824170
# 14                                           0.830482
# 15                                           1.064224
# 16                                           1.054836
# 17                                           0.913640
# 18                                           0.914035
# 19                                           0.683625
# 20                                           1.170166
# 21                                           1.171866
# 22                                           1.321524
# 23                                           1.339174
# 24                                           1.543555
# 25                                           0.815182
# 26                                           1.024394
# 27                                           1.518362
# 28                                           1.851455
# 29                                           1.039796
# 30                                           1.883217
# 31                                           0.764928
# 32                                           0.690768
# 33                                           0.832928
# 34                                           0.742659
# 35                                           1.081052
# 36                                           0.934577
# 37                                           1.184691
# 38                                           1.351562
# 39                                           0.749772
# 40                                           1.570908
# 41                                           1.880922
# 42                                           0.813801
# 43                                           4.698370
# 44                                           1.055664
#
#     final_val_loss_ci_lower_MikiV_SimpleStories_SimpleStories_subchunked_128x4  \
# 0                                            0.611220
# 1                                            0.602794
# 2                                            0.601147
# 3                                            0.635187
# 4                                            0.642881
# 5                                            0.696954
# 6                                            0.634734
# 7                                            0.697805
# 8                                            0.683142
# 9                                            0.705225
# 10                                           0.755590
# 11                                           0.753192
# 12                                           0.741789
# 13                                           0.822545
# 14                                           0.828881
# 15                                           1.062483
# 16                                           1.053168
# 17                                           0.912047
# 18                                           0.912359
# 19                                           0.682331
# 20                                           1.168412
# 21                                           1.170114
# 22                                           1.319854
# 23                                           1.337581
# 24                                           1.542209
# 25                                           0.813772
# 26                                           1.022721
# 27                                           1.516952
# 28                                           1.850414
# 29                                           1.038147
# 30                                           1.882240
# 31                                           0.763408
# 32                                           0.689420
# 33                                           0.831304
# 34                                           0.741299
# 35                                           1.079291
# 36                                           0.932943
# 37                                           1.182992
# 38                                           1.349942
# 39                                           0.748416
# 40                                           1.569529
# 41                                           1.879870
# 42                                           0.812394
# 43                                           4.698055
# 44                                           1.053979
#
#     final_val_loss_ci_upper_MikiV_SimpleStories_SimpleStories_subchunked_128x4
# 0                                            0.613660
# 1                                            0.605257
# 2                                            0.603570
# 3                                            0.637671
# 4                                            0.645421
# 5                                            0.699936
# 6                                            0.637185
# 7                                            0.700779
# 8                                            0.685791
# 9                                            0.708270
# 10                                           0.758687
# 11                                           0.756282
# 12                                           0.744507
# 13                                           0.825791
# 14                                           0.832104
# 15                                           1.065947
# 16                                           1.056551
# 17                                           0.915253
# 18                                           0.915731
# 19                                           0.684908
# 20                                           1.171929
# 21                                           1.173605
# 22                                           1.323149
# 23                                           1.340741
# 24                                           1.544918
# 25                                           0.816617
# 26                                           1.026084
# 27                                           1.519737
# 28                                           1.852543
# 29                                           1.041553
# 30                                           1.884213
# 31                                           0.766433
# 32                                           0.692059
# 33                                           0.834520
# 34                                           0.744057
# 35                                           1.082815
# 36                                           0.936288
# 37                                           1.186406
# 38                                           1.353221
# 39                                           0.751127
# 40                                           1.572264
# 41                                           1.881964
# 42                                           0.815236
# 43                                           4.698687
# 44                                           1.057345

# %%
runs_df = runs_df[runs_df['run_name'].str.contains('512')]
val_loss_col = 'final_val_loss_MikiV_SimpleStories_SimpleStories_chunked_512'

print("There are ", len(runs_df), " runs")
runs_df_finished = runs_df[runs_df['params'].notnull()]
print("There are ", len(runs_df_finished), " finished runs")

runs_df = runs_df_finished
runs_df = runs_df.astype(dtypes)
# Out:
# There are  15  runs
# There are  15  finished runs

# %%
import torch.nn as nn
class ScalingLaw(torch.nn.Module):
    """
    We model the loss as a function of number of parameters N and dataset size D as:
    $$
    \hat{L}(N, D) \triangleq E+\frac{A}{N^\alpha}+\frac{B}{D^\beta}
    $$
    """
    def __init__(self, a=0.0, b=0.0, e=0.0, alpha=0.5, beta=0.5):
        super().__init__()
        self.a = nn.Parameter(torch.tensor(a, dtype=torch.float32))
        self.b = nn.Parameter(torch.tensor(b, dtype=torch.float32))
        self.e = nn.Parameter(torch.tensor(e, dtype=torch.float32))
        self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32))
        self.beta = nn.Parameter(torch.tensor(beta, dtype=torch.float32))

    def forward(self, N, D):
        """
        N: tensor of model sizes (number of parameters)
        D: tensor of dataset sizes
        returns: predicted loss (same shape as N and D)
        """
        A = torch.exp(self.a)
        B = torch.exp(self.b)
        E = torch.exp(self.e)
        return E + A / (N ** self.alpha) + B / (D ** self.beta)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\h'
# <>:6: SyntaxWarning: invalid escape sequence '\h'
# /tmp/ipykernel_134041/280072866.py:6: SyntaxWarning: invalid escape sequence '\h'
#   \hat{L}(N, D) \triangleq E+\frac{A}{N^\alpha}+\frac{B}{D^\beta}

# %%
N = torch.tensor(pd.to_numeric(runs_df['params']).values, dtype=torch.float32)
D = torch.tensor(pd.to_numeric(runs_df['tokens_seen']).values, dtype=torch.float32)
L = torch.tensor(runs_df[val_loss_col].values, dtype=torch.float32)
X = torch.cat([N.unsqueeze(1), D.unsqueeze(1)], dim=1)
y = L

criterion = nn.HuberLoss(delta=1e-3)
total_epochs = 10000
learning_rate = 1e-3

# Containers for results
preds = torch.zeros_like(y)

models = []
for i in range(len(X)):
    print(f"LOOCV: leaving out sample {i+1}/{len(X)}")

    # Split train/val
    train_mask = torch.ones(len(X), dtype=bool)

    train_mask[i] = False

    X_train, y_train = X[train_mask], y[train_mask]
    X_val, y_val = X[~train_mask], y[~train_mask]

    # Initialize new model for each fold
    model = ScalingLaw()
    optimizer = optim.AdamW(model.parameters(), lr=1e-2, weight_decay=1e-9)
    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=total_epochs)

    # --- Train ---
    for epoch in range(total_epochs):
        model.train()
        optimizer.zero_grad()
        L_pred = model(X_train[:, 0], X_train[:, 1])
        loss = criterion(torch.log(L_pred), torch.log(y_train))
        loss.backward()
        optimizer.step()
        lr_scheduler.step()

    # --- Predict on left-out sample ---
    model.eval()
    with torch.no_grad():
        pred = model(X_val[:, 0], X_val[:, 1])
        preds[i] = pred
    models.append(model)

# Write results back to the dataframe
runs_df['pred'] = preds.detach().numpy().flatten()
runs_df['error_abs'] = (runs_df['pred'] - runs_df[val_loss_col]).abs()
runs_df['error_rel'] = runs_df['error_abs'] / runs_df[val_loss_col]

# Show results sorted by largest absolute error
result_df = runs_df[['run_name', val_loss_col, 'pred', 'error_abs', 'error_rel']] \
    .sort_values(by='error_abs', ascending=False)
result_df
# Out:
# LOOCV: leaving out sample 1/15
# LOOCV: leaving out sample 2/15
# LOOCV: leaving out sample 3/15
# LOOCV: leaving out sample 4/15
# LOOCV: leaving out sample 5/15
# LOOCV: leaving out sample 6/15
# LOOCV: leaving out sample 7/15
# LOOCV: leaving out sample 8/15
# LOOCV: leaving out sample 9/15
# LOOCV: leaving out sample 10/15
# LOOCV: leaving out sample 11/15
# LOOCV: leaving out sample 12/15
# LOOCV: leaving out sample 13/15
# LOOCV: leaving out sample 14/15
# LOOCV: leaving out sample 15/15
#                                       run_name  \
# 43  cfgs/simple_stories_chartok/512/14M/1.yaml
# 41   cfgs/simple_stories_chartok/512/2M/1.yaml
# 40   cfgs/simple_stories_chartok/512/2M/2.yaml
# 35   cfgs/simple_stories_chartok/512/2M/5.yaml
# 37   cfgs/simple_stories_chartok/512/2M/4.yaml
# 38   cfgs/simple_stories_chartok/512/2M/3.yaml
# 44   cfgs/simple_stories_chartok/512/7M/1.yaml
# 36   cfgs/simple_stories_chartok/512/7M/2.yaml
# 39  cfgs/simple_stories_chartok/512/14M/2.yaml
# 0   cfgs/simple_stories_chartok/512/14M/5.yaml
# 32  cfgs/simple_stories_chartok/512/14M/3.yaml
# 9    cfgs/simple_stories_chartok/512/7M/5.yaml
# 4   cfgs/simple_stories_chartok/512/14M/4.yaml
# 33   cfgs/simple_stories_chartok/512/7M/3.yaml
# 31   cfgs/simple_stories_chartok/512/7M/4.yaml
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_chunked_512       pred  \
# 43                                           4.700279             12.797815
# 41                                           1.858666              1.517368
# 40                                           1.531610              1.370510
# 35                                           1.028272              1.112067
# 37                                           1.135678              1.201894
# 38                                           1.308330              1.244898
# 44                                           1.001073              0.951203
# 36                                           0.875178              0.848231
# 39                                           0.669744              0.695273
# 0                                            0.505827              0.486299
# 32                                           0.599458              0.616251
# 9                                            0.616713              0.624959
# 4                                            0.544180              0.547445
# 33                                           0.763294              0.760505
# 31                                           0.683746              0.686457
#
#     error_abs  error_rel
# 43   8.097537   1.722778
# 41   0.341298   0.183625
# 40   0.161100   0.105184
# 35   0.083794   0.081490
# 37   0.066216   0.058305
# 38   0.063432   0.048483
# 44   0.049870   0.049817
# 36   0.026947   0.030790
# 39   0.025529   0.038117
# 0    0.019528   0.038606
# 32   0.016793   0.028014
# 9    0.008246   0.013371
# 4    0.003265   0.006000
# 33   0.002789   0.003653
# 31   0.002712   0.003966

# %%
from math import exp
As = np.array([exp(m.a.item()) for m in models])
Bs = np.array([exp(m.b.item()) for m in models])
Es = np.array([exp(m.e.item()) for m in models])
alphas = np.array([m.alpha.item() for m in models])
betas = np.array([m.beta.item() for m in models])

# Boxplots of the parameters
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
axs[0, 0].boxplot(As)
axs[0, 0].set_title('A values')
axs[0, 1].boxplot(Bs)
axs[0, 1].set_title('B values')
axs[0, 2].boxplot(Es)
axs[0, 2].set_title('E values')
axs[1, 0].boxplot(alphas)
axs[1, 0].set_title('alpha values')
axs[1, 1].boxplot(betas)
axs[1, 1].set_title('beta values')
plt.tight_layout()
plt.show()

# %%
 
total_epochs = 20000
model = ScalingLaw()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=total_epochs)
for epoch in range(total_epochs):
    model.train()
    optimizer.zero_grad()
    L_pred = model(N, D)
    loss = criterion(torch.log(L_pred), torch.log(L))
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.0004314556426834315
# Epoch 100, Loss: 0.00042247577221132815
# Epoch 200, Loss: 0.00039507148903794587
# Epoch 300, Loss: 0.0003766664594877511
# Epoch 400, Loss: 0.0003629769489634782
# Epoch 500, Loss: 0.0003510030801407993
# Epoch 600, Loss: 0.0003400295681785792
# Epoch 700, Loss: 0.0003296138602308929
# Epoch 800, Loss: 0.00031944975489750504
# Epoch 900, Loss: 0.00030931783840060234
# Epoch 1000, Loss: 0.00029902407550252974
# Epoch 1100, Loss: 0.0002885567082557827
# Epoch 1200, Loss: 0.0002779786882456392
# Epoch 1300, Loss: 0.0002676415315363556
# Epoch 1400, Loss: 0.00025702317361719906
# Epoch 1500, Loss: 0.0002465075522195548
# Epoch 1600, Loss: 0.0002362517116125673
# Epoch 1700, Loss: 0.0002257350570289418
# Epoch 1800, Loss: 0.00021556518913712353
# Epoch 1900, Loss: 0.00020548939937725663
# Epoch 2000, Loss: 0.00019537140906322747
# Epoch 2100, Loss: 0.0001852307323133573
# Epoch 2200, Loss: 0.00017510946781840175
# Epoch 2300, Loss: 0.00016537122428417206
# Epoch 2400, Loss: 0.00015536976570729166
# Epoch 2500, Loss: 0.000145708690979518
# Epoch 2600, Loss: 0.00013619751553051174
# Epoch 2700, Loss: 0.00012681246153078973
# Epoch 2800, Loss: 0.00011746952804969624
# Epoch 2900, Loss: 0.00010818557348102331
# Epoch 3000, Loss: 9.891776426229626e-05
# Epoch 3100, Loss: 9.013868839247152e-05
# Epoch 3200, Loss: 8.325180533574894e-05
# Epoch 3300, Loss: 7.753449608571827e-05
# Epoch 3400, Loss: 7.236600504256785e-05
# Epoch 3500, Loss: 6.753989873686805e-05
# Epoch 3600, Loss: 6.285942799877375e-05
# Epoch 3700, Loss: 5.9760957810794935e-05
# Epoch 3800, Loss: 5.7584438764024526e-05
# Epoch 3900, Loss: 5.53917525394354e-05
# Epoch 4000, Loss: 5.393209357862361e-05
# Epoch 4100, Loss: 5.2625568059738725e-05
# Epoch 4200, Loss: 5.148955460754223e-05
# Epoch 4300, Loss: 5.028297891840339e-05
# Epoch 4400, Loss: 4.9156544264405966e-05
# Epoch 4500, Loss: 4.799780435860157e-05
# Epoch 4600, Loss: 4.684655868913978e-05
# Epoch 4700, Loss: 4.580019958666526e-05
# Epoch 4800, Loss: 4.492997322813608e-05
# Epoch 4900, Loss: 4.4371699914336205e-05
# Epoch 5000, Loss: 4.401052137836814e-05
# Epoch 5100, Loss: 4.3764324800577015e-05
# Epoch 5200, Loss: 4.356382487458177e-05
# Epoch 5300, Loss: 4.336168785812333e-05
# Epoch 5400, Loss: 4.315809565014206e-05
# Epoch 5500, Loss: 4.29981664638035e-05
# Epoch 5600, Loss: 4.2881889385171235e-05
# Epoch 5700, Loss: 4.282685404177755e-05
# Epoch 5800, Loss: 4.2471769120311365e-05
# Epoch 5900, Loss: 4.232909850543365e-05
# Epoch 6000, Loss: 4.218655885779299e-05
# Epoch 6100, Loss: 4.204407014185563e-05
# Epoch 6200, Loss: 4.19018542743288e-05
# Epoch 6300, Loss: 4.176003858447075e-05
# Epoch 6400, Loss: 4.161871038377285e-05
# Epoch 6500, Loss: 4.147805884713307e-05
# Epoch 6600, Loss: 4.134012124268338e-05
# Epoch 6700, Loss: 4.1202052670996636e-05
# Epoch 6800, Loss: 4.106892447452992e-05
# Epoch 6900, Loss: 4.0935436118161306e-05
# Epoch 7000, Loss: 4.080644066561945e-05
# Epoch 7100, Loss: 4.0688682929612696e-05
# Epoch 7200, Loss: 4.055041790707037e-05
# Epoch 7300, Loss: 4.044314846396446e-05
# Epoch 7400, Loss: 4.03217418352142e-05
# Epoch 7500, Loss: 4.02115001634229e-05
# Epoch 7600, Loss: 4.010335396742448e-05
# Epoch 7700, Loss: 3.999636828666553e-05
# Epoch 7800, Loss: 3.989003744209185e-05
# Epoch 7900, Loss: 3.9788297726772726e-05
# Epoch 8000, Loss: 3.968413147958927e-05
# Epoch 8100, Loss: 3.958614615839906e-05
# Epoch 8200, Loss: 3.94837225030642e-05
# Epoch 8300, Loss: 3.93834343412891e-05
# Epoch 8400, Loss: 3.928610749426298e-05
# Epoch 8500, Loss: 3.931987885152921e-05
# Epoch 8600, Loss: 3.9107293559936807e-05
# Epoch 8700, Loss: 3.902188836946152e-05
# Epoch 8800, Loss: 3.8936886994633824e-05
# Epoch 8900, Loss: 3.885216574417427e-05
# Epoch 9000, Loss: 3.876768096233718e-05
# Epoch 9100, Loss: 3.8683265302097425e-05
# Epoch 9200, Loss: 3.8598780520260334e-05
# Epoch 9300, Loss: 3.851411383948289e-05
# Epoch 9400, Loss: 3.842903970507905e-05
# Epoch 9500, Loss: 3.83434489776846e-05
# Epoch 9600, Loss: 3.825796375167556e-05
# Epoch 9700, Loss: 3.817448305198923e-05
# Epoch 9800, Loss: 3.810207635979168e-05
# Epoch 9900, Loss: 3.800247941398993e-05
# Epoch 10000, Loss: 3.791358176385984e-05
# Epoch 10100, Loss: 3.78274817194324e-05
# Epoch 10200, Loss: 3.774061769945547e-05
# Epoch 10300, Loss: 3.765196379390545e-05
# Epoch 10400, Loss: 3.756278965738602e-05
# Epoch 10500, Loss: 3.74879855371546e-05
# Epoch 10600, Loss: 3.73827206203714e-05
# Epoch 10700, Loss: 3.7291687476681545e-05
# Epoch 10800, Loss: 3.7199984944891185e-05
# Epoch 10900, Loss: 3.822215148829855e-05
# Epoch 11000, Loss: 3.7098761822562665e-05
# Epoch 11100, Loss: 3.704839400597848e-05
# Epoch 11200, Loss: 3.6977024137740955e-05
# Epoch 11300, Loss: 3.693473991006613e-05
# Epoch 11400, Loss: 3.68932232959196e-05
# Epoch 11500, Loss: 3.685166302602738e-05
# Epoch 11600, Loss: 3.6809939047088847e-05
# Epoch 11700, Loss: 3.676806954899803e-05
# Epoch 11800, Loss: 3.6726079997606575e-05
# Epoch 11900, Loss: 3.668391946121119e-05
# Epoch 12000, Loss: 3.664164250949398e-05
# Epoch 12100, Loss: 3.6599289160221815e-05
# Epoch 12200, Loss: 3.655683030956425e-05
# Epoch 12300, Loss: 3.651430597528815e-05
# Epoch 12400, Loss: 3.6471708881435916e-05
# Epoch 12500, Loss: 3.642907540779561e-05
# Epoch 12600, Loss: 3.6388526496011764e-05
# Epoch 12700, Loss: 3.6352463212097064e-05
# Epoch 12800, Loss: 3.631613071775064e-05
# Epoch 12900, Loss: 3.628275226219557e-05
# Epoch 13000, Loss: 3.624930468504317e-05
# Epoch 13100, Loss: 3.621584255597554e-05
# Epoch 13200, Loss: 3.6182300391374156e-05
# Epoch 13300, Loss: 3.6148765502730384e-05
# Epoch 13400, Loss: 3.61152742698323e-05
# Epoch 13500, Loss: 3.6081790312891826e-05
# Epoch 13600, Loss: 3.6048353649675846e-05
# Epoch 13700, Loss: 3.601497519412078e-05
# Epoch 13800, Loss: 3.5981705877929926e-05
# Epoch 13900, Loss: 3.594856025301851e-05
# Epoch 14000, Loss: 3.591560016502626e-05
# Epoch 14100, Loss: 3.588280742405914e-05
# Epoch 14200, Loss: 3.585022932384163e-05
# Epoch 14300, Loss: 3.581798227969557e-05
# Epoch 14400, Loss: 3.5786117223324254e-05
# Epoch 14500, Loss: 3.575498703867197e-05
# Epoch 14600, Loss: 3.5724671761272475e-05
# Epoch 14700, Loss: 3.5694469261216e-05
# Epoch 14800, Loss: 3.566511077224277e-05
# Epoch 14900, Loss: 3.563641075743362e-05
# Epoch 15000, Loss: 3.5608314647106454e-05
# Epoch 15100, Loss: 3.5580869734985754e-05
# Epoch 15200, Loss: 3.555426519596949e-05
# Epoch 15300, Loss: 3.552778434823267e-05
# Epoch 15400, Loss: 3.5502125683706254e-05
# Epoch 15500, Loss: 3.5477154597174376e-05
# Epoch 15600, Loss: 3.545280560501851e-05
# Epoch 15700, Loss: 3.542907870723866e-05
# Epoch 15800, Loss: 3.5406043025432155e-05
# Epoch 15900, Loss: 3.538365490385331e-05
# Epoch 16000, Loss: 3.536197618814185e-05
# Epoch 16100, Loss: 3.5340970498509705e-05
# Epoch 16200, Loss: 3.532068876666017e-05
# Epoch 16300, Loss: 3.530112371663563e-05
# Epoch 16400, Loss: 3.528227534843609e-05
# Epoch 16500, Loss: 3.526419459376484e-05
# Epoch 16600, Loss: 3.524685962474905e-05
# Epoch 16700, Loss: 3.5230339562986046e-05
# Epoch 16800, Loss: 3.5214528907090425e-05
# Epoch 16900, Loss: 3.5199518606532365e-05
# Epoch 17000, Loss: 3.518530138535425e-05
# Epoch 17100, Loss: 3.517185177770443e-05
# Epoch 17200, Loss: 3.5159187973476946e-05
# Epoch 17300, Loss: 3.5147255402989686e-05
# Epoch 17400, Loss: 3.5136112273903564e-05
# Epoch 17500, Loss: 3.512569674057886e-05
# Epoch 17600, Loss: 3.5116019716951996e-05
# Epoch 17700, Loss: 3.510702299536206e-05
# Epoch 17800, Loss: 3.509876114549115e-05
# Epoch 17900, Loss: 3.509116140776314e-05
# Epoch 18000, Loss: 3.508419467834756e-05
# Epoch 18100, Loss: 3.5077842767350376e-05
# Epoch 18200, Loss: 3.507211658870801e-05
# Epoch 18300, Loss: 3.5066972486674786e-05
# Epoch 18400, Loss: 3.506238863337785e-05
# Epoch 18500, Loss: 3.505829954519868e-05
# Epoch 18600, Loss: 3.5054727050010115e-05
# Epoch 18700, Loss: 3.505160930217244e-05
# Epoch 18800, Loss: 3.504894266370684e-05
# Epoch 18900, Loss: 3.504665437503718e-05
# Epoch 19000, Loss: 3.5044755350099877e-05
# Epoch 19100, Loss: 3.504320193314925e-05
# Epoch 19200, Loss: 3.504195046843961e-05
# Epoch 19300, Loss: 3.50409718521405e-05
# Epoch 19400, Loss: 3.5040215152548626e-05
# Epoch 19500, Loss: 3.503973130136728e-05
# Epoch 19600, Loss: 3.503937114146538e-05
# Epoch 19700, Loss: 3.503914558677934e-05
# Epoch 19800, Loss: 3.5039029171457514e-05
# Epoch 19900, Loss: 3.5039014619542286e-05

# %%
preds = model(N, D)
runs_df['pred'] = preds.detach().numpy().flatten()
runs_df['error_abs'] = (runs_df['pred'] - runs_df[val_loss_col]).abs()
runs_df['error_rel'] = runs_df['error_abs'] / runs_df[val_loss_col]
runs_df[['run_name', val_loss_col, 'pred', 'error_abs', 'error_rel']].sort_values(by='error_abs', ascending=False)
# Out:
#                                       run_name  \
# 41   cfgs/simple_stories_chartok/512/2M/1.yaml
# 40   cfgs/simple_stories_chartok/512/2M/2.yaml
# 35   cfgs/simple_stories_chartok/512/2M/5.yaml
# 37   cfgs/simple_stories_chartok/512/2M/4.yaml
# 44   cfgs/simple_stories_chartok/512/7M/1.yaml
# 36   cfgs/simple_stories_chartok/512/7M/2.yaml
# 38   cfgs/simple_stories_chartok/512/2M/3.yaml
# 0   cfgs/simple_stories_chartok/512/14M/5.yaml
# 39  cfgs/simple_stories_chartok/512/14M/2.yaml
# 32  cfgs/simple_stories_chartok/512/14M/3.yaml
# 43  cfgs/simple_stories_chartok/512/14M/1.yaml
# 33   cfgs/simple_stories_chartok/512/7M/3.yaml
# 9    cfgs/simple_stories_chartok/512/7M/5.yaml
# 31   cfgs/simple_stories_chartok/512/7M/4.yaml
# 4   cfgs/simple_stories_chartok/512/14M/4.yaml
#
#     final_val_loss_MikiV_SimpleStories_SimpleStories_chunked_512      pred  \
# 41                                           1.858666             1.560614
# 40                                           1.531610             1.415085
# 35                                           1.028272             1.092691
# 37                                           1.135678             1.183950
# 44                                           1.001073             0.953881
# 36                                           0.875178             0.849795
# 38                                           1.308330             1.290550
# 0                                            0.505827             0.488464
# 39                                           0.669744             0.686043
# 32                                           0.599458             0.609738
# 43                                           4.700279             4.703312
# 33                                           0.763294             0.760675
# 9                                            0.616713             0.619035
# 31                                           0.683746             0.684370
# 4                                            0.544180             0.544404
#
#     error_abs  error_rel
# 41   0.298052   0.160358
# 40   0.116525   0.076080
# 35   0.064419   0.062648
# 37   0.048272   0.042505
# 44   0.047192   0.047141
# 36   0.025383   0.029004
# 38   0.017780   0.013590
# 0    0.017362   0.034324
# 39   0.016299   0.024337
# 32   0.010280   0.017149
# 43   0.003033   0.000645
# 33   0.002619   0.003431
# 9    0.002322   0.003765
# 31   0.000624   0.000913
# 4    0.000224   0.000412

# %%
A = torch.exp(model.a).item()
B = torch.exp(model.b).item()
E = torch.exp(model.e).item()
alpha = model.alpha.item()
beta = model.beta.item()
print(f"A={A}, B={B}, E={E}, alpha={alpha}, beta={beta}")
# Out:
# A=486.3199462890625, B=46.67914581298828, E=0.004775532986968756, alpha=0.4991587698459625, beta=0.22396636009216309
